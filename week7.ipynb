# %% [markdown]
# # Import

# %%
import numpy as np
import pandas as pd

# Set random seed to ensure reproducible runs
RSEED = 50

# %%
X = np.array([[2, 2],
              [2, 1],
              [2, 3],
              [1, 2],
              [1, 1],
              [3, 3]])

y = np.array([0, 1, 1, 1, 0, 1])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# Plot formatting
plt.style.use('fivethirtyeight')
plt.rcParams['font.size'] = 18
plt.figure(figsize = (8, 8))

# Plot each point as the label
for x1, x2, label in zip(X[:, 0], X[:, 1], y):
    plt.text(x1, x2, str(label), fontsize = 40, color = 'g',
             ha='center', va='center')

# Plot formatting
plt.grid(None);
plt.xlim((0, 3.5));
plt.ylim((0, 3.5));
plt.xlabel('x1', size = 20); plt.ylabel('x2', size = 20); plt.title('Data', size = 24)
# Out:
# Text(0.5, 1.0, 'Data')

# %%
from sklearn.tree import DecisionTreeClassifier

# Make a decision tree and train
tree = DecisionTreeClassifier(random_state=RSEED)
tree.fit(X, y)
# Out:
# DecisionTreeClassifier(random_state=50)

# %%
print(f'Decision tree has {tree.tree_.node_count} nodes with maximum depth {tree.tree_.max_depth}.')
# Out:
# Decision tree has 9 nodes with maximum depth 3.

# %%
print(f'Model Accuracy: {tree.score(X, y)}')
# Out:
# Model Accuracy: 1.0

# %%
from sklearn.tree import export_graphviz

# Export as dot
export_graphviz(tree, 'tree.dot', rounded = True,
                feature_names = ['x1', 'x2'],
                class_names = ['0', '1'], filled = True)

# %%
from subprocess import call

# Convert to png
call(['dot', '-Tpng', 'tree.dot', '-o', 'tree.png', '-Gdpi=400']);
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 4
#       1 from subprocess import call
#       3 # Convert to png
# ----> 4 call(['dot', '-Tpng', 'tree.dot', '-o', 'tree.png', '-Gdpi=400'])
#
# File ~/anaconda3/envs/Ai-Tutorials/lib/python3.12/subprocess.py:389, in call(timeout, *popenargs, **kwargs)
#     381 def call(*popenargs, timeout=None, **kwargs):
#     382     """Run command with arguments.  Wait for command to complete or
#     383     for timeout seconds, then return the returncode attribute.
#     384
#    (...)
#     387     retcode = call(["ls", "-l"])
#     388     """
# --> 389     with Popen(*popenargs, **kwargs) as p:
#     390         try:
#     391             return p.wait(timeout=timeout)
#
# File ~/anaconda3/envs/Ai-Tutorials/lib/python3.12/subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1022         if self.text_mode:
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#    1037     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~/anaconda3/envs/Ai-Tutorials/lib/python3.12/subprocess.py:1955, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1953     err_msg = os.strerror(errno_num)
#    1954 if err_filename is not None:
# -> 1955     raise child_exception_type(errno_num, err_msg, err_filename)
#    1956 else:
#    1957     raise child_exception_type(errno_num, err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dot'

# %%
from IPython.display import Image
Image('tree.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/envs/Ai-Tutorials/lib/python3.12/site-packages/IPython/core/display.py:1045, in Image._data_and_metadata(self, always_both)
#    1044 try:
# -> 1045     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1046 except TypeError as e:
#
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~/anaconda3/envs/Ai-Tutorials/lib/python3.12/site-packages/IPython/core/formatters.py:974, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     971     method = get_real_method(obj, self.print_method)
#     973     if method is not None:
# --> 974         return method(include=include, exclude=exclude)
#     975     return None
#     976 else:
#
# File ~/anaconda3/envs/Ai-Tutorials/lib/python3.12/site-packages/IPython/core/display.py:1035, in Image._repr_mimebundle_(self, include, exclude)
#    1033 if self.embed:
#    1034     mimetype = self._mimetype
# -> 1035     data, metadata = self._data_and_metadata(always_both=True)
#    1036     if metadata:
#    1037         metadata = {mimetype: metadata}
#
# File ~/anaconda3/envs/Ai-Tutorials/lib/python3.12/site-packages/IPython/core/display.py:1047, in Image._data_and_metadata(self, always_both)
#    1045     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1046 except TypeError as e:
# -> 1047     raise FileNotFoundError(
#    1048         "No such file or directory: '%s'" % (self.data)) from e
#    1049 md = {}
#    1050 if self.metadata:
#
# FileNotFoundError: No such file or directory: 'tree.png'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/envs/Ai-Tutorials/lib/python3.12/site-packages/IPython/core/display.py:1045, in Image._data_and_metadata(self, always_both)
#    1044 try:
# -> 1045     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1046 except TypeError as e:
#
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~/anaconda3/envs/Ai-Tutorials/lib/python3.12/site-packages/IPython/core/formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File ~/anaconda3/envs/Ai-Tutorials/lib/python3.12/site-packages/IPython/core/display.py:1067, in Image._repr_png_(self)
#    1065 def _repr_png_(self):
#    1066     if self.embed and self.format == self._FMT_PNG:
# -> 1067         return self._data_and_metadata()
#
# File ~/anaconda3/envs/Ai-Tutorials/lib/python3.12/site-packages/IPython/core/display.py:1047, in Image._data_and_metadata(self, always_both)
#    1045     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1046 except TypeError as e:
# -> 1047     raise FileNotFoundError(
#    1048         "No such file or directory: '%s'" % (self.data)) from e
#    1049 md = {}
#    1050 if self.metadata:
#
# FileNotFoundError: No such file or directory: 'tree.png'

# %%
df = pd.read_csv('data/2015.csv').sample(5000, random_state=RSEED)
df.head()
# Out:
# /var/folders/_l/vdgqbw4x0q99dgnnpmyn9v3m0000gn/T/ipykernel_45867/1167501287.py:1: DtypeWarning: Columns (2,3,4,5,197,224,225) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/2015.csv').sample(5000, random_state=RSEED)
#        _STATE  FMONTH        IDATE IMONTH   IDAY    IYEAR  DISPCODE  \
# 9711      2.0     7.0  b'07082015'  b'07'  b'08'  b'2015'    1100.0
# 14815     NaN     NaN          NaN    NaN    NaN      NaN       NaN
# 7470      1.0    11.0  b'11062015'  b'11'  b'06'  b'2015'    1100.0
# 16168     NaN     NaN          NaN    NaN    NaN      NaN       NaN
# 5323      1.0     6.0  b'06112015'  b'06'  b'11'  b'2015'    1100.0
#
#               SEQNO          _PSU  CTELENUM  ...  _PAREC1  _PASTAE1  _LMTACT1  \
# 9711   2.015002e+09  2.015002e+09       1.0  ...      2.0       2.0       3.0
# 14815           NaN           NaN       NaN  ...      NaN       NaN       NaN
# 7470   2.015007e+09  2.015007e+09       NaN  ...      4.0       2.0       3.0
# 16168           NaN           NaN       NaN  ...      NaN       NaN       NaN
# 5323   2.015005e+09  2.015005e+09       NaN  ...      1.0       1.0       1.0
#
#        _LMTWRK1  _LMTSCL1  _RFSEAT2  _RFSEAT3  _FLSHOT6  _PNEUMO2  _AIDTST3
# 9711        3.0       4.0       1.0       1.0       NaN       NaN       1.0
# 14815       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 7470        3.0       4.0       1.0       1.0       NaN       NaN       2.0
# 16168       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 5323        1.0       3.0       1.0       1.0       NaN       NaN       1.0
#
# [5 rows x 330 columns]
