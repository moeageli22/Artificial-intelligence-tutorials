# %% [markdown]
# # Import

# %%
import numpy as np
import pandas as pd

# Set random seed to ensure reproducible runs
RSEED = 50

# %%
X = np.array([[2, 2],
              [2, 1],
              [2, 3],
              [1, 2],
              [1, 1],
              [3, 3]])

y = np.array([0, 1, 1, 1, 0, 1])
